# %%
import sys
sys.path.append("..")
import spark_utils
spark_utils.print_ui_links()
# Out:
# NameNode: http://ec2-3-235-150-104.compute-1.amazonaws.com:50070
# YARN: http://ec2-3-235-150-104.compute-1.amazonaws.com:8088
# Spark UI: http://ec2-3-235-150-104.compute-1.amazonaws.com:20888/proxy/application_1620307932889_0002

# %% [markdown]
# # YARN config
#
# https://hadoop.apache.org/docs/current/hadoop-yarn/hadoop-yarn-common/yarn-default.xml

# %%
! cat /etc/hadoop/conf/yarn-site.xml | egrep -A 1 "mb|cpu-vcores"
# Out:
#     <name>yarn.scheduler.increment-allocation-mb</name>
#     <value>32</value>
# --
#     <name>yarn.nodemanager.resource.cpu-vcores</name>
#     <value>8</value>
# --
#     <name>yarn.scheduler.maximum-allocation-mb</name>
#     <value>57344</value>
# --
#     <name>yarn.nodemanager.resource.memory-mb</name>
#     <value>57344</value>
# --
#     <name>yarn.scheduler.minimum-allocation-mb</name>
#     <value>32</value>

# %% [markdown]
# # MapReduce config

# %% [markdown]
# https://hadoop.apache.org/docs/current/hadoop-mapreduce-client/hadoop-mapreduce-client-core/mapred-default.xml

# %%
! cat /etc/hadoop/conf/mapred-site.xml | egrep -A 1 "mb"
# Out:
#     <name>mapreduce.task.io.sort.mb</name>
#     <value>200</value>
# --
#     <name>mapreduce.map.memory.mb</name>
#     <value>7168</value>
# --
#     <name>mapreduce.reduce.memory.mb</name>
#     <value>14336</value>
# --
#     <name>yarn.app.mapreduce.am.resource.mb</name>
#     <value>14336</value>

# %% [markdown]
# # Wikipedia dataset

# %%
# download from s3 to local disk (you can also read them directly with Hadoop though)
! aws s3 cp s3://ydatazian/week1 . --recursive
# Out:
# download: s3://ydatazian/week1/categories.jsonl to ./categories.jsonl
# download: s3://ydatazian/week1/wiki.jsonl to ./wiki.jsonl

# %%
! ls -lh .
# Out:
# total 205M
# -rw-rw-r-- 1 hadoop hadoop  61M May  6 21:11 categories.jsonl
# -rw-rw-r-- 1 hadoop hadoop  149 May  6 21:54 generate.py
# -rw-rw-r-- 1 hadoop hadoop  27K May  6 21:55 hdfs-basics.ipynb
# -rw-rw-r-- 1 hadoop hadoop  24K May  6 22:01 mapreduce-wordcount.ipynb
# -rw-r--r-- 1 hadoop hadoop   10 May  6 21:18 test2.txt
# -rw-rw-r-- 1 hadoop hadoop   10 May  6 21:53 test.txt
# -rw-rw-r-- 1 hadoop hadoop 144M May  6 21:11 wiki.jsonl

# %%
! head -n 1 wiki.jsonl
# Out:
# {"title": "April", "text": "April\n\nApril is the fourth month of the year, and comes between March and May. It is one of four months to have 30 days.\n\nApril always begins on the same day of week as July, and additionally, January in leap years. April always ends on the same day of the week as December.\n\nApril's flowers are the Sweet Pea and Daisy. Its birthstone is the diamond. The meaning of the diamond is innocence.\n\nApril comes between March and May, making it the fourth month of the year. It also comes first in the year out of the four months that have 30 days, as June, September and November are later in the year.\n\nApril begins on the same day of the week as July every year and on the same day of the week as January in leap years. April ends on the same day of the week as December every year, as each other's last days are exactly 35 weeks (245 days) apart.\n\nIn common years, April starts on the same day of the week as October of the previous year, and in leap years, May of the previous year. In common years, April finishes on the same day of the week as July of the previous year, and in leap years, February and October of the previous year. In common years immediately after other common years, April starts on the same day of the week as January of the previous year, and in leap years and years immediately after that, April finishes on the same day of the week as January of the previous year.\n\nIn years immediately before common years, April starts on the same day of the week as September and December of the following year, and in years immediately before leap years, June of the following year. In years immediately before common years, April finishes on the same day of the week as September of the following year, and in years immediately before leap years, March and June of the following year.\n\nApril is a spring month in the Northern Hemisphere and an autumn/fall month in the Southern Hemisphere. In each hemisphere, it is the seasonal equivalent of October in the other.\n\nIt is unclear as to where April got its name. A common theory is that it comes from the Latin word \"aperire\", meaning \"to open\", referring to flowers opening in spring. Another theory is that the name could come from Aphrodite, the Greek goddess of love. It was originally the second month in the old Roman Calendar, before the start of the new year was put to January 1.\n\nQuite a few festivals are held in this month. In many Southeast Asian cultures, new year is celebrated in this month (including Songkran). In Western Christianity, Easter can be celebrated on a Sunday between March 22 and April 25. In Orthodox Christianity, it can fall between April 4 and May 8. At the end of the month, Central and Northern European cultures celebrate Walpurgis Night on April 30, marking the transition from winter into summer.\n\nPoets use \"April\" to mean the end of winter. For example: \"April showers bring May flowers.\"\n\n\n", "url": "https://simple.wikipedia.org/wiki?curid=1", "id": "1"}

# %%
# make a sample
! head -n 1000 wiki.jsonl > sample.jsonl

# %% [markdown]
# # WordCount mapper
#
# https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html

# %%
# %%file mapper.py
import sys
import json
import re
import string

for line in sys.stdin:
    text = json.loads(line)['text']
    text = re.sub(f'[^{re.escape(string.printable)}]', ' ', text)  # not printable to space
    words = text.lower().split()
    for word in words:
        print(word + "\t" + "1")
# Out:
# Writing mapper.py

# %% [markdown]
# # Test mapper

# %%
! echo "{\"text\": \"This  is  text\"}" | python3 ./mapper.py
# Out:
# this	1
# is	1
# text	1

# %% [markdown]
# # WordCount reducer
#
# https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html

# %%
# reducer input
! python3 -c "print('\n'.join(['aaa\t1'] * 10 + ['bbb\t1'] * 5))"
# Out:
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# aaa	1
# bbb	1
# bbb	1
# bbb	1
# bbb	1
# bbb	1

# %%
# %%file reducer.py
import sys

prev_key = None
count = 0
for line in sys.stdin:  # stream is sorted by key
    key, value = line.split("\t")
    
    if prev_key is not None and key != prev_key:
        # new key in stream, dump previous
        print(prev_key + "\t" + str(count))
        count = 0
    
    count += int(value)
    prev_key = key

# dump last key
print(prev_key + "\t" + str(count))
# Out:
# Writing reducer.py

# %% [markdown]
# # Test reducer

# %%
! python3 -c "print('\n'.join(['aaa\t1'] * 10 + ['bbb\t1'] * 5))" | python3 ./reducer.py
# Out:
# aaa	10
# bbb	5

# %% [markdown]
# # Test MapReduce locally

# %%
# %%bash
# cat sample.jsonl | python3 ./mapper.py | sort -k 1,1 -t $'\t' | python3 ./reducer.py > result.txt
# cat result.txt | sort -k 2,2 -t $'\t' -n -r | head -n 10
# Out:
# the	34538
# of	15944
# and	12966
# in	12448
# a	11322
# is	10870
# to	9469
# are	5598
# it	4330
# that	4057

# %% [markdown]
# # Copy files to HDFS

# %%
! hadoop fs -copyFromLocal *.jsonl /

# %%
! hadoop fs -ls -h /
# Out:
# Found 10 items
# -rw-r--r--   1 hadoop hadoop    128.0 M 2021-05-06 21:54 /128.txt
# -rw-r--r--   1 hadoop hadoop    256.0 M 2021-05-06 21:54 /256.txt
# -rw-r--r--   1 hadoop hadoop     60.9 M 2021-05-06 22:07 /categories.jsonl
# -rw-r--r--   1 hadoop hadoop      2.9 M 2021-05-06 22:07 /sample.jsonl
# -rw-r--r--   2 hadoop hadoop         10 2021-05-06 21:18 /test.txt
# -rw-r--r--   1 hadoop hadoop          8 2021-05-06 21:19 /test3.txt
# drwxrwxrwt   - hdfs   hadoop          0 2021-05-06 13:32 /tmp
# drwxr-xr-x   - hdfs   hadoop          0 2021-05-06 13:32 /user
# drwxr-xr-x   - hdfs   hadoop          0 2021-05-06 13:32 /var
# -rw-r--r--   1 hadoop hadoop    143.4 M 2021-05-06 22:07 /wiki.jsonl

# %% [markdown]
# # Run on Hadoop
#
# https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html
#
# https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html#Packaging_Files_With_Job_Submissions

# %%
! which python3
# Out:
# /usr/bin/python3

# %%
! hadoop fs -rm -r /word-count

! hadoop jar /usr/lib/hadoop/hadoop-streaming.jar \
  -input /sample.jsonl \
  -output /word-count \
  -mapper "/usr/bin/python3 mapper.py" \
  -reducer "/usr/bin/python3 reducer.py" \
  -file mapper.py \
  -file reducer.py
# Out:
# rm: `/word-count': No such file or directory
# 21/05/06 22:12:10 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.8.5-amzn-5.jar] /tmp/streamjob1600431364475733951.jar tmpDir=null
# 21/05/06 22:12:11 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:12:11 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:12:12 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 21/05/06 22:12:12 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 5f788d5e8f90539ee331702c753fa250727128f4]
# 21/05/06 22:12:12 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/05/06 22:12:12 INFO mapreduce.JobSubmitter: number of splits:16
# 21/05/06 22:12:12 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1620307932889_0004
# 21/05/06 22:12:12 INFO impl.YarnClientImpl: Submitted application application_1620307932889_0004
# 21/05/06 22:12:12 INFO mapreduce.Job: The url to track the job: http://ip-172-31-13-255.ec2.internal:20888/proxy/application_1620307932889_0004/
# 21/05/06 22:12:12 INFO mapreduce.Job: Running job: job_1620307932889_0004
# 21/05/06 22:12:17 INFO mapreduce.Job: Job job_1620307932889_0004 running in uber mode : false
# 21/05/06 22:12:17 INFO mapreduce.Job:  map 0% reduce 0%
# 21/05/06 22:12:22 INFO mapreduce.Job:  map 6% reduce 0%
# 21/05/06 22:12:24 INFO mapreduce.Job:  map 50% reduce 0%
# 21/05/06 22:12:25 INFO mapreduce.Job:  map 56% reduce 0%
# 21/05/06 22:12:26 INFO mapreduce.Job:  map 69% reduce 0%
# 21/05/06 22:12:27 INFO mapreduce.Job:  map 81% reduce 0%
# 21/05/06 22:12:28 INFO mapreduce.Job:  map 100% reduce 0%
# 21/05/06 22:12:30 INFO mapreduce.Job:  map 100% reduce 43%
# 21/05/06 22:12:31 INFO mapreduce.Job:  map 100% reduce 71%
# 21/05/06 22:12:32 INFO mapreduce.Job:  map 100% reduce 86%
# 21/05/06 22:12:33 INFO mapreduce.Job:  map 100% reduce 100%
# 21/05/06 22:12:35 INFO mapreduce.Job: Job job_1620307932889_0004 completed successfully
# 21/05/06 22:12:35 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=658043
# 		FILE: Number of bytes written=5892975
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3266376
# 		HDFS: Number of bytes written=522039
# 		HDFS: Number of read operations=69
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=17
# 		Launched reduce tasks=7
# 		Data-local map tasks=9
# 		Rack-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=16146816
# 		Total time spent by all reduces in occupied slots (ms)=9116352
# 		Total time spent by all map tasks (ms)=72084
# 		Total time spent by all reduce tasks (ms)=20349
# 		Total vcore-milliseconds taken by all map tasks=72084
# 		Total vcore-milliseconds taken by all reduce tasks=20349
# 		Total megabyte-milliseconds taken by all map tasks=516698112
# 		Total megabyte-milliseconds taken by all reduce tasks=291723264
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=484654
# 		Map output bytes=3820586
# 		Map output materialized bytes=1247429
# 		Input split bytes=1696
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=48539
# 		Reduce shuffle bytes=1247429
# 		Reduce input records=484654
# 		Reduce output records=48539
# 		Spilled Records=969308
# 		Shuffled Maps =112
# 		Failed Shuffles=0
# 		Merged Map outputs=112
# 		GC time elapsed (ms)=2527
# 		CPU time spent (ms)=31820
# 		Physical memory (bytes) snapshot=11357487104
# 		Virtual memory (bytes) snapshot=231931097088
# 		Total committed heap usage (bytes)=17651204096
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3264680
# 	File Output Format Counters
# 		Bytes Written=522039
# 21/05/06 22:12:35 INFO streaming.StreamJob: Output directory: /word-count

# %%
! hadoop fs -ls /word-count
# Out:
# Found 8 items
# -rw-r--r--   1 hadoop hadoop          0 2021-05-06 22:12 /word-count/_SUCCESS
# -rw-r--r--   1 hadoop hadoop      73746 2021-05-06 22:12 /word-count/part-00000
# -rw-r--r--   1 hadoop hadoop      74194 2021-05-06 22:12 /word-count/part-00001
# -rw-r--r--   1 hadoop hadoop      73981 2021-05-06 22:12 /word-count/part-00002
# -rw-r--r--   1 hadoop hadoop      75232 2021-05-06 22:12 /word-count/part-00003
# -rw-r--r--   1 hadoop hadoop      74032 2021-05-06 22:12 /word-count/part-00004
# -rw-r--r--   1 hadoop hadoop      76532 2021-05-06 22:12 /word-count/part-00005
# -rw-r--r--   1 hadoop hadoop      74322 2021-05-06 22:12 /word-count/part-00006

# %%
# %%bash
# hadoop fs -cat "/word-count/*" | sort -k 2,2 -t $'\t' -n -r | head -n 10
# Out:
# the	34538
# of	15944
# and	12966
# in	12448
# a	11322
# is	10870
# to	9469
# are	5598
# it	4330
# that	4057

# %% [markdown]
# # Debugging mapper

# %%
# %%file mapper.py
import sys
import json
import re
import string

for line in sys.stdin:
    text = json.loads(line)['text123']  # error: missing key!
    text = re.sub(f'[^{re.escape(string.printable)}]', ' ', text)  # not printable to space
    words = text.lower().split()
    for word in words:
        print(word + "\t" + "1")
# Out:
# Overwriting mapper.py

# %%
! hadoop fs -rm -r /word-count

! hadoop jar /usr/lib/hadoop/hadoop-streaming.jar \
  -input /sample.jsonl \
  -output /word-count \
  -mapper "/usr/bin/python3 mapper.py" \
  -reducer "/usr/bin/python3 reducer.py" \
  -file mapper.py \
  -file reducer.py
# Out:
# Deleted /word-count
# 21/05/06 22:14:14 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.8.5-amzn-5.jar] /tmp/streamjob3331255832138617194.jar tmpDir=null
# 21/05/06 22:14:14 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:14:15 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:14:15 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 21/05/06 22:14:15 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 5f788d5e8f90539ee331702c753fa250727128f4]
# 21/05/06 22:14:15 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/05/06 22:14:15 INFO mapreduce.JobSubmitter: number of splits:16
# 21/05/06 22:14:15 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1620307932889_0005
# 21/05/06 22:14:15 INFO impl.YarnClientImpl: Submitted application application_1620307932889_0005
# 21/05/06 22:14:15 INFO mapreduce.Job: The url to track the job: http://ip-172-31-13-255.ec2.internal:20888/proxy/application_1620307932889_0005/
# 21/05/06 22:14:15 INFO mapreduce.Job: Running job: job_1620307932889_0005
# 21/05/06 22:14:20 INFO mapreduce.Job: Job job_1620307932889_0005 running in uber mode : false
# 21/05/06 22:14:20 INFO mapreduce.Job:  map 0% reduce 0%
# 21/05/06 22:14:24 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000006_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000007_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000008_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000002_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:26 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000000_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:26 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000001_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:26 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000005_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:26 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000003_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:26 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000004_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:27 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000009_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:27 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000010_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:28 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000012_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:28 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000011_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:28 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000006_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000003_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000007_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000002_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000009_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000008_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000000_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000005_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000004_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:32 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000001_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:33 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000010_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:33 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000012_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:33 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000011_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:34 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000006_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:36 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000013_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000008_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000000_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000003_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000005_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000007_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000004_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000002_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000009_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:38 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000001_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:39 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000012_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:39 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000011_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:40 INFO mapreduce.Job: Task Id : attempt_1620307932889_0005_m_000010_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:455)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:344)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:14:41 INFO mapreduce.Job:  map 100% reduce 100%
# 21/05/06 22:14:43 INFO mapreduce.Job: Job job_1620307932889_0005 failed with state FAILED due to: Task failed task_1620307932889_0005_m_000006
# Job failed as tasks failed. failedMaps:1 failedReduces:0
#
# 21/05/06 22:14:44 INFO mapreduce.Job: Counters: 18
# 	Job Counters
# 		Failed map tasks=41
# 		Killed map tasks=15
# 		Killed reduce tasks=7
# 		Launched map tasks=50
# 		Other local map tasks=36
# 		Data-local map tasks=7
# 		Rack-local map tasks=7
# 		Total time spent by all maps in occupied slots (ms)=40356064
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total time spent by all map tasks (ms)=180161
# 		Total time spent by all reduce tasks (ms)=0
# 		Total vcore-milliseconds taken by all map tasks=180161
# 		Total vcore-milliseconds taken by all reduce tasks=0
# 		Total megabyte-milliseconds taken by all map tasks=1291394048
# 		Total megabyte-milliseconds taken by all reduce tasks=0
# 	Map-Reduce Framework
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 21/05/06 22:14:44 ERROR streaming.StreamJob: Job not successful!
# Streaming Command Failed!

# %% [markdown]
# # Debugging reducer

# %%
# %%file mapper.py
import sys
import json
import re
import string

for line in sys.stdin:
    text = json.loads(line)['text']
    text = re.sub(f'[^{re.escape(string.printable)}]', ' ', text)  # not printable to space
    words = text.lower().split()
    for word in words:
        print(word + "\n" + "1")  # error: reducer will fail!
# Out:
# Overwriting mapper.py

# %%
! hadoop fs -rm -r /word-count

! hadoop jar /usr/lib/hadoop/hadoop-streaming.jar \
  -input /sample.jsonl \
  -output /word-count \
  -mapper "/usr/bin/python3 mapper.py" \
  -reducer "/usr/bin/python3 reducer.py" \
  -file mapper.py \
  -file reducer.py
# Out:
# Deleted /word-count
# 21/05/06 22:15:27 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py, reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.8.5-amzn-5.jar] /tmp/streamjob8786550264471346840.jar tmpDir=null
# 21/05/06 22:15:27 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:15:28 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:15:28 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 21/05/06 22:15:28 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 5f788d5e8f90539ee331702c753fa250727128f4]
# 21/05/06 22:15:28 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/05/06 22:15:28 INFO mapreduce.JobSubmitter: number of splits:16
# 21/05/06 22:15:28 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1620307932889_0006
# 21/05/06 22:15:29 INFO impl.YarnClientImpl: Submitted application application_1620307932889_0006
# 21/05/06 22:15:29 INFO mapreduce.Job: The url to track the job: http://ip-172-31-13-255.ec2.internal:20888/proxy/application_1620307932889_0006/
# 21/05/06 22:15:29 INFO mapreduce.Job: Running job: job_1620307932889_0006
# 21/05/06 22:15:34 INFO mapreduce.Job: Job job_1620307932889_0006 running in uber mode : false
# 21/05/06 22:15:34 INFO mapreduce.Job:  map 0% reduce 0%
# 21/05/06 22:15:39 INFO mapreduce.Job:  map 6% reduce 0%
# 21/05/06 22:15:40 INFO mapreduce.Job:  map 19% reduce 0%
# 21/05/06 22:15:41 INFO mapreduce.Job:  map 25% reduce 0%
# 21/05/06 22:15:42 INFO mapreduce.Job:  map 31% reduce 0%
# 21/05/06 22:15:43 INFO mapreduce.Job:  map 81% reduce 0%
# 21/05/06 22:15:44 INFO mapreduce.Job:  map 88% reduce 0%
# 21/05/06 22:15:45 INFO mapreduce.Job:  map 100% reduce 0%
# 21/05/06 22:15:45 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000000_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:46 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000001_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:46 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000002_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:46 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000003_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:47 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000004_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:47 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000005_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:48 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000006_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:49 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000000_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:50 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000003_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:52 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000005_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:52 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000004_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:52 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000002_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:52 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000001_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:53 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000006_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:53 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000000_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:55 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000003_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:57 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000002_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:57 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000001_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:58 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000004_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:58 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000005_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:15:59 INFO mapreduce.Job: Task Id : attempt_1620307932889_0006_r_000006_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:251)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:467)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:393)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1844)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 21/05/06 22:16:00 INFO mapreduce.Job:  map 100% reduce 100%
# 21/05/06 22:16:00 INFO mapreduce.Job: Job job_1620307932889_0006 failed with state FAILED due to: Task failed task_1620307932889_0006_r_000000
# Job failed as tasks failed. failedMaps:0 failedReduces:1
#
# 21/05/06 22:16:00 INFO mapreduce.Job: Counters: 40
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=4089980
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3266376
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of read operations=48
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=0
# 	Job Counters
# 		Failed reduce tasks=22
# 		Killed map tasks=1
# 		Killed reduce tasks=6
# 		Launched map tasks=16
# 		Launched reduce tasks=23
# 		Data-local map tasks=8
# 		Rack-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=18608800
# 		Total time spent by all reduces in occupied slots (ms)=27913536
# 		Total time spent by all map tasks (ms)=83075
# 		Total time spent by all reduce tasks (ms)=62307
# 		Total vcore-milliseconds taken by all map tasks=83075
# 		Total vcore-milliseconds taken by all reduce tasks=62307
# 		Total megabyte-milliseconds taken by all map tasks=595481600
# 		Total megabyte-milliseconds taken by all reduce tasks=893233152
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=969308
# 		Map output bytes=4789894
# 		Map output materialized bytes=1315094
# 		Input split bytes=1696
# 		Combine input records=0
# 		Spilled Records=969308
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=2283
# 		CPU time spent (ms)=21650
# 		Physical memory (bytes) snapshot=8991383552
# 		Virtual memory (bytes) snapshot=130938363904
# 		Total committed heap usage (bytes)=12242649088
# 	File Input Format Counters
# 		Bytes Read=3264680
# 21/05/06 22:16:00 ERROR streaming.StreamJob: Job not successful!
# Streaming Command Failed!

# %% [markdown]
# # Debugging memory usage

# %%
# %%file mapper.py
import sys
import numpy as np

matrix = np.ones((int(3 * 1024 * 1024 * 1024),), dtype=np.uint8) # 3 gb
s = matrix.sum()

for line in sys.stdin:
    print(str(s))
# Out:
# Overwriting mapper.py

# %%
! hadoop fs -rm -r /test

! hadoop jar /usr/lib/hadoop/hadoop-streaming.jar \
  -Dmapreduce.map.memory.mb=4096 \
  -input /sample.jsonl \
  -output /test \
  -mapper "/usr/bin/python3 mapper.py" \
  -file mapper.py
# Out:
# Deleted /test
# 21/05/06 22:21:14 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py] [/usr/lib/hadoop/hadoop-streaming-2.8.5-amzn-5.jar] /tmp/streamjob2629747957270035408.jar tmpDir=null
# 21/05/06 22:21:14 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:21:15 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:21:15 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 21/05/06 22:21:15 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 5f788d5e8f90539ee331702c753fa250727128f4]
# 21/05/06 22:21:15 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/05/06 22:21:15 INFO mapreduce.JobSubmitter: number of splits:16
# 21/05/06 22:21:15 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1620307932889_0009
# 21/05/06 22:21:15 INFO impl.YarnClientImpl: Submitted application application_1620307932889_0009
# 21/05/06 22:21:15 INFO mapreduce.Job: The url to track the job: http://ip-172-31-13-255.ec2.internal:20888/proxy/application_1620307932889_0009/
# 21/05/06 22:21:15 INFO mapreduce.Job: Running job: job_1620307932889_0009
# 21/05/06 22:21:20 INFO mapreduce.Job: Job job_1620307932889_0009 running in uber mode : false
# 21/05/06 22:21:20 INFO mapreduce.Job:  map 0% reduce 0%
# 21/05/06 22:21:38 INFO mapreduce.Job:  map 6% reduce 0%
# 21/05/06 22:21:39 INFO mapreduce.Job:  map 63% reduce 0%
# 21/05/06 22:21:50 INFO mapreduce.Job:  map 69% reduce 0%
# 21/05/06 22:21:51 INFO mapreduce.Job:  map 75% reduce 0%
# 21/05/06 22:21:52 INFO mapreduce.Job:  map 100% reduce 43%
# 21/05/06 22:21:53 INFO mapreduce.Job:  map 100% reduce 57%
# 21/05/06 22:21:55 INFO mapreduce.Job:  map 100% reduce 100%
# 21/05/06 22:21:56 INFO mapreduce.Job: Job job_1620307932889_0009 completed successfully
# 21/05/06 22:21:57 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=813
# 		FILE: Number of bytes written=3967389
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3266376
# 		HDFS: Number of bytes written=12000
# 		HDFS: Number of read operations=69
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=16
# 		Launched reduce tasks=7
# 		Data-local map tasks=16
# 		Total time spent by all maps in occupied slots (ms)=30758016
# 		Total time spent by all reduces in occupied slots (ms)=22739584
# 		Total time spent by all map tasks (ms)=240297
# 		Total time spent by all reduce tasks (ms)=50758
# 		Total vcore-milliseconds taken by all map tasks=240297
# 		Total vcore-milliseconds taken by all reduce tasks=50758
# 		Total megabyte-milliseconds taken by all map tasks=984256512
# 		Total megabyte-milliseconds taken by all reduce tasks=727666688
# 	Map-Reduce Framework
# 		Map input records=1000
# 		Map output records=1000
# 		Map output bytes=12000
# 		Map output materialized bytes=2717
# 		Input split bytes=1696
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=2717
# 		Reduce input records=1000
# 		Reduce output records=1000
# 		Spilled Records=2000
# 		Shuffled Maps =112
# 		Failed Shuffles=0
# 		Merged Map outputs=112
# 		GC time elapsed (ms)=3631
# 		CPU time spent (ms)=18080
# 		Physical memory (bytes) snapshot=11260481536
# 		Virtual memory (bytes) snapshot=231902560256
# 		Total committed heap usage (bytes)=17554735104
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3264680
# 	File Output Format Counters
# 		Bytes Written=12000
# 21/05/06 22:21:57 INFO streaming.StreamJob: Output directory: /test

# %%
! hadoop fs -rm -r /test

! hadoop jar /usr/lib/hadoop/hadoop-streaming.jar \
  -Dmapreduce.map.memory.mb=2048 \
  -input /sample.jsonl \
  -output /test \
  -mapper "/usr/bin/python3 mapper.py" \
  -file mapper.py
# Out:
# Deleted /test
# 21/05/06 22:19:43 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper.py] [/usr/lib/hadoop/hadoop-streaming-2.8.5-amzn-5.jar] /tmp/streamjob2142224779299513657.jar tmpDir=null
# 21/05/06 22:19:44 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:19:44 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-13-255.ec2.internal/172.31.13.255:8032
# 21/05/06 22:19:45 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 21/05/06 22:19:45 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 5f788d5e8f90539ee331702c753fa250727128f4]
# 21/05/06 22:19:45 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/05/06 22:19:45 INFO mapreduce.JobSubmitter: number of splits:16
# 21/05/06 22:19:45 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1620307932889_0008
# 21/05/06 22:19:45 INFO impl.YarnClientImpl: Submitted application application_1620307932889_0008
# 21/05/06 22:19:45 INFO mapreduce.Job: The url to track the job: http://ip-172-31-13-255.ec2.internal:20888/proxy/application_1620307932889_0008/
# 21/05/06 22:19:45 INFO mapreduce.Job: Running job: job_1620307932889_0008
# 21/05/06 22:19:50 INFO mapreduce.Job: Job job_1620307932889_0008 running in uber mode : false
# 21/05/06 22:19:50 INFO mapreduce.Job:  map 0% reduce 0%
# 21/05/06 22:20:09 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000008_0, Status : FAILED
# Container [pid=20938,containerID=container_1620307932889_0008_01_000010] is running beyond virtual memory limits. Current usage: 2.1 GB of 2 GB physical memory used; 11.2 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000010 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20938 20932 20938 20938 (bash) 0 0 115871744 679 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000010/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000010 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000008_0 10 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000010/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000010/stderr
# 	|- 21009 20938 20938 20938 (java) 730 46 8069644288 140405 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000010/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000010 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000008_0 10
# 	|- 21700 21009 20938 20938 (python3) 82 99 3786936320 415652 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:10 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000009_0, Status : FAILED
# Container [pid=20824,containerID=container_1620307932889_0008_01_000011] is running beyond virtual memory limits. Current usage: 2.1 GB of 2 GB physical memory used; 11.2 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000011 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20873 20824 20824 20824 (java) 725 37 8089845760 147107 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000011/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000011 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000009_0 11
# 	|- 21729 20873 20824 20824 (python3) 73 100 3787001856 399191 /usr/bin/python3 mapper.py
# 	|- 20824 20821 20824 20824 (bash) 0 0 115871744 679 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000011/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000011 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000009_0 11 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000011/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000011/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:10 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000010_0, Status : FAILED
# Container [pid=20950,containerID=container_1620307932889_0008_01_000012] is running beyond virtual memory limits. Current usage: 2.4 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000012 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20950 20941 20950 20950 (bash) 0 0 115871744 685 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000012/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000012 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000010_0 12 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000012/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000012/stderr
# 	|- 21047 20950 20950 20950 (java) 568 33 8062783488 132174 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000012/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000012 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000010_0 12
# 	|- 21595 21047 20950 20950 (python3) 98 104 3786932224 507392 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000011_0, Status : FAILED
# Container [pid=20958,containerID=container_1620307932889_0008_01_000013] is running beyond virtual memory limits. Current usage: 2.4 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000013 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21053 20958 20958 20958 (java) 650 40 8061329408 136860 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000013/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000013 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000011_0 13
# 	|- 20958 20951 20958 20958 (bash) 0 0 115871744 694 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000013/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000013 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000011_0 13 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000013/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000013/stderr
# 	|- 21601 21053 20958 20958 (python3) 87 117 3786936320 484814 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000004_0, Status : FAILED
# Container [pid=20842,containerID=container_1620307932889_0008_01_000006] is running beyond virtual memory limits. Current usage: 2.4 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000006 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21591 20910 20842 20842 (python3) 93 114 3786862592 496738 /usr/bin/python3 mapper.py
# 	|- 20910 20842 20842 20842 (java) 561 32 8061693952 131676 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000006/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000006 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000004_0 6
# 	|- 20842 20828 20842 20842 (bash) 0 0 115871744 675 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000006/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000006 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000004_0 6 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000006/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000006/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000005_0, Status : FAILED
# Container [pid=20906,containerID=container_1620307932889_0008_01_000007] is running beyond virtual memory limits. Current usage: 2.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000007 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21654 20981 20906 20906 (python3) 101 110 3787001856 533908 /usr/bin/python3 mapper.py
# 	|- 20981 20906 20906 20906 (java) 566 37 8061878272 132020 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000007/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000007 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000005_0 7
# 	|- 20906 20902 20906 20906 (bash) 0 0 115871744 666 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000007/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000007 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000005_0 7 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000007/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000007/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000006_0, Status : FAILED
# Container [pid=20845,containerID=container_1620307932889_0008_01_000008] is running beyond virtual memory limits. Current usage: 2.4 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000008 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20845 20834 20845 20845 (bash) 0 0 115871744 681 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000008/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000008 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000006_0 8 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000008/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000008/stderr
# 	|- 21604 20887 20845 20845 (python3) 91 112 3787001856 496684 /usr/bin/python3 mapper.py
# 	|- 20887 20845 20845 20845 (java) 727 45 8057380864 140241 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000008/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000008 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000006_0 8
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000007_0, Status : FAILED
# Container [pid=20844,containerID=container_1620307932889_0008_01_000009] is running beyond virtual memory limits. Current usage: 2.9 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000009 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20874 20844 20844 20844 (java) 584 34 8062640128 132825 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000009/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000009 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000007_0 9
# 	|- 20844 20832 20844 20844 (bash) 0 0 115871744 677 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000009/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000009 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000007_0 9 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000009/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000009/stderr
# 	|- 21546 20874 20844 20844 (python3) 95 137 3786862592 624558 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000000_0, Status : FAILED
# Container [pid=20797,containerID=container_1620307932889_0008_01_000002] is running beyond virtual memory limits. Current usage: 2.9 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000002 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20797 20794 20797 20797 (bash) 0 0 115871744 679 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000002/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000002 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000000_0 2 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000002/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000002/stderr
# 	|- 21550 20806 20797 20797 (python3) 105 134 3786936320 614577 /usr/bin/python3 mapper.py
# 	|- 20806 20797 20797 20797 (java) 583 35 8062488576 132274 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000002/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000002 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000000_0 2
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000001_0, Status : FAILED
# Container [pid=20831,containerID=container_1620307932889_0008_01_000003] is running beyond virtual memory limits. Current usage: 2.4 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000003 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21590 20922 20831 20831 (python3) 93 110 3787001856 494759 /usr/bin/python3 mapper.py
# 	|- 20922 20831 20831 20831 (java) 624 42 8063287296 136148 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000003/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000003 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000001_0 3
# 	|- 20831 20823 20831 20831 (bash) 0 0 115871744 691 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000003/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000003 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000001_0 3 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000003/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000003/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000002_0, Status : FAILED
# Container [pid=20835,containerID=container_1620307932889_0008_01_000004] is running beyond virtual memory limits. Current usage: 2.3 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000004 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21718 20867 20835 20835 (python3) 94 108 3786936320 468609 /usr/bin/python3 mapper.py
# 	|- 20835 20830 20835 20835 (bash) 0 0 115871744 679 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000004/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000004 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000002_0 4 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000004/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000004/stderr
# 	|- 20867 20835 20835 20835 (java) 557 35 8062492672 131845 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000004/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000004 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000002_0 4
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000003_0, Status : FAILED
# Container [pid=20838,containerID=container_1620307932889_0008_01_000005] is running beyond virtual memory limits. Current usage: 2.7 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000005 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20871 20838 20838 20838 (java) 574 34 8063471616 132306 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000005/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000005 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000003_0 5
# 	|- 20838 20822 20838 20838 (bash) 0 0 115871744 662 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000005/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000005 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000003_0 5 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000005/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000005/stderr
# 	|- 21592 20871 20838 20838 (python3) 99 126 3786932224 565053 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:11 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000012_0, Status : FAILED
# Container [pid=20999,containerID=container_1620307932889_0008_01_000014] is running beyond virtual memory limits. Current usage: 2.6 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000014 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21655 21064 20999 20999 (python3) 97 124 3786936320 542873 /usr/bin/python3 mapper.py
# 	|- 21064 20999 20999 20999 (java) 571 34 8061542400 132156 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000014/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000014 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000012_0 14
# 	|- 20999 20948 20999 20999 (bash) 0 0 115871744 677 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000014/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000014 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000012_0 14 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000014/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000014/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:12 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000013_0, Status : FAILED
# Container [pid=20959,containerID=container_1620307932889_0008_01_000015] is running beyond virtual memory limits. Current usage: 2.7 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000015 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20995 20959 20959 20959 (java) 557 41 8062050304 131925 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000015/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000015 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000013_0 15
# 	|- 20959 20942 20959 20959 (bash) 0 0 115871744 660 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000015/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000015 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000013_0 15 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000015/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000015/stderr
# 	|- 21705 20995 20959 20959 (python3) 95 132 3787001856 577659 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:12 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000014_0, Status : FAILED
# Container [pid=20962,containerID=container_1620307932889_0008_01_000016] is running beyond virtual memory limits. Current usage: 2.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000016 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 20962 20954 20962 20962 (bash) 0 0 115871744 702 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000016/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000016 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000014_0 16 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000016/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000016/stderr
# 	|- 21039 20962 20962 20962 (java) 564 38 8063647744 132381 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000016/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000016 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000014_0 16
# 	|- 21623 21039 20962 20962 (python3) 94 118 3786932224 512472 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:12 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000015_0, Status : FAILED
# Container [pid=20944,containerID=container_1620307932889_0008_01_000017] is running beyond virtual memory limits. Current usage: 2.9 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000017 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21015 20944 20944 20944 (java) 553 41 8057380864 131579 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000017/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000017 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000015_0 17
# 	|- 21585 21015 20944 20944 (python3) 108 143 3786936320 631246 /usr/bin/python3 mapper.py
# 	|- 20944 20926 20944 20944 (bash) 0 0 115871744 662 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000017/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000017 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000015_0 17 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000017/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000017/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:20 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000008_1, Status : FAILED
# Container [pid=21988,containerID=container_1620307932889_0008_01_000018] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000018 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 21993 21988 21988 21988 (java) 407 25 8065327104 132657 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000018/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000018 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000008_1 18
# 	|- 22040 21993 21988 21988 (python3) 326 166 3786932224 794138 /usr/bin/python3 mapper.py
# 	|- 21988 21986 21988 21988 (bash) 0 0 115871744 688 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000018/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000018 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000008_1 18 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000018/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000018/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:23 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000006_1, Status : FAILED
# Container [pid=22091,containerID=container_1620307932889_0008_01_000024] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000024 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22091 22088 22091 22091 (bash) 0 0 115871744 680 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000024/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000024 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000006_1 24 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000024/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000024/stderr
# 	|- 22118 22091 22091 22091 (java) 554 37 8067059712 134176 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000024/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000024 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000006_1 24
# 	|- 22332 22118 22091 22091 (python3) 210 137 3786866688 794203 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000009_1, Status : FAILED
# Container [pid=22106,containerID=container_1620307932889_0008_01_000019] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000019 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22119 22106 22106 22106 (java) 538 35 8063119360 133075 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000019/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000019 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000009_1 19
# 	|- 22450 22119 22106 22106 (python3) 246 166 3786936320 794173 /usr/bin/python3 mapper.py
# 	|- 22106 22104 22106 22106 (bash) 0 0 115871744 666 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000019/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000019 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000009_1 19 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000019/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000019/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000010_1, Status : FAILED
# Container [pid=22116,containerID=container_1620307932889_0008_01_000020] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000020 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22474 22128 22116 22116 (python3) 286 149 3786932224 794180 /usr/bin/python3 mapper.py
# 	|- 22116 22109 22116 22116 (bash) 0 0 115871744 687 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000020/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000020 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000010_1 20 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000020/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000020/stderr
# 	|- 22128 22116 22116 22116 (java) 523 38 8063574016 132992 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000020/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000020 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000010_1 20
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:25 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000011_1, Status : FAILED
# Container [pid=22115,containerID=container_1620307932889_0008_01_000021] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000021 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22464 22127 22115 22115 (python3) 285 160 3786936320 794186 /usr/bin/python3 mapper.py
# ...
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:41 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000005_2, Status : FAILED
# Container [pid=23010,containerID=container_1620307932889_0008_01_000070] is running beyond virtual memory limits. Current usage: 3.6 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000070 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 23040 23010 23010 23010 (java) 629 43 8062849024 137815 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000070/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000070 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000005_2 70
# 	|- 23010 23005 23010 23010 (bash) 0 0 115871744 663 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000070/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000070 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000005_2 70 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000070/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000070/stderr
# 	|- 23413 23040 23010 23010 (python3) 152 185 3786936320 794139 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:41 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000014_2, Status : FAILED
# Container [pid=22877,containerID=container_1620307932889_0008_01_000055] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000055 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22877 22876 22877 22877 (bash) 0 0 115871744 685 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000055/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000055 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000014_2 55 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000055/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000055/stderr
# 	|- 23331 22887 22877 22877 (python3) 250 187 3786866688 794210 /usr/bin/python3 mapper.py
# 	|- 22887 22877 22877 22877 (java) 564 35 8062840832 132686 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000055/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000055 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000014_2 55
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:41 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000002_2, Status : FAILED
# Container [pid=22917,containerID=container_1620307932889_0008_01_000056] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000056 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22943 22917 22917 22917 (java) 555 33 8061816832 131805 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000056/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000056 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000002_2 56
# 	|- 22917 22902 22917 22917 (bash) 0 0 115871744 661 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000056/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000056 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000002_2 56 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000056/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000056/stderr
# 	|- 23327 22943 22917 22917 (python3) 268 167 3787001856 794142 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:41 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000001_2, Status : FAILED
# Container [pid=22997,containerID=container_1620307932889_0008_01_000068] is running beyond virtual memory limits. Current usage: 3.6 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000068 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 23009 22997 22997 22997 (java) 642 39 8061681664 139404 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000068/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000068 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000001_2 68
# 	|- 23401 23009 22997 22997 (python3) 188 154 3786936320 794181 /usr/bin/python3 mapper.py
# 	|- 22997 22996 22997 22997 (bash) 0 0 115871744 686 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000068/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000068 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000001_2 68 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000068/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000068/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:41 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000004_2, Status : FAILED
# Container [pid=23014,containerID=container_1620307932889_0008_01_000069] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000069 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 23385 23035 23014 23014 (python3) 222 141 3787001856 794180 /usr/bin/python3 mapper.py
# 	|- 23035 23014 23014 23014 (java) 567 38 8062623744 132319 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000069/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000069 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000004_2 69
# 	|- 23014 23006 23014 23014 (bash) 0 0 115871744 682 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000069/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000069 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000004_2 69 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000069/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000069/stderr
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:42 INFO mapreduce.Job: Task Id : attempt_1620307932889_0008_m_000013_2, Status : FAILED
# Container [pid=22806,containerID=container_1620307932889_0008_01_000071] is running beyond virtual memory limits. Current usage: 3.5 GB of 2 GB physical memory used; 11.1 GB of 10 GB virtual memory used. Killing container.
# Dump of the process-tree for container_1620307932889_0008_01_000071 :
# 	|- PID PPID PGRPID SESSID CMD_NAME USER_MODE_TIME(MILLIS) SYSTEM_TIME(MILLIS) VMEM_USAGE(BYTES) RSSMEM_USAGE(PAGES) FULL_CMD_LINE
# 	|- 22822 22806 22806 22806 (java) 555 34 8060669952 131653 /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000071/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000071 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000013_2 71
# 	|- 22806 22803 22806 22806 (bash) 0 0 115871744 675 /bin/bash -c /usr/lib/jvm/java-openjdk/bin/java -Djava.net.preferIPv4Stack=true -Dhadoop.metrics.log.level=WARN  -Xmx5734m -Djava.io.tmpdir=/mnt/yarn/usercache/hadoop/appcache/application_1620307932889_0008/container_1620307932889_0008_01_000071/tmp -Dlog4j.configuration=container-log4j.properties -Dyarn.app.container.log.dir=/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000071 -Dyarn.app.container.log.filesize=0 -Dhadoop.root.logger=INFO,CLA -Dhadoop.root.logfile=syslog org.apache.hadoop.mapred.YarnChild 172.31.4.27 43407 attempt_1620307932889_0008_m_000013_2 71 1>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000071/stdout 2>/var/log/hadoop-yarn/containers/application_1620307932889_0008/container_1620307932889_0008_01_000071/stderr
# 	|- 23116 22822 22806 22806 (python3) 418 155 3787001856 794179 /usr/bin/python3 mapper.py
#
# Container killed on request. Exit code is 143
# Container exited with a non-zero exit code 143
#
# 21/05/06 22:20:43 INFO mapreduce.Job:  map 100% reduce 100%
# 21/05/06 22:20:44 INFO mapreduce.Job: Job job_1620307932889_0008 failed with state FAILED due to: Task failed task_1620307932889_0008_m_000008
# Job failed as tasks failed. failedMaps:1 failedReduces:0
#
# 21/05/06 22:20:44 INFO mapreduce.Job: Counters: 40
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=172572
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=196530
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of read operations=3
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=0
# 	Job Counters
# 		Failed map tasks=46
# 		Killed map tasks=14
# 		Killed reduce tasks=7
# 		Launched map tasks=57
# 		Launched reduce tasks=5
# 		Other local map tasks=41
# 		Data-local map tasks=16
# 		Total time spent by all maps in occupied slots (ms)=45190656
# 		Total time spent by all reduces in occupied slots (ms)=26455744
# 		Total time spent by all map tasks (ms)=706104
# 		Total time spent by all reduce tasks (ms)=59053
# 		Total vcore-milliseconds taken by all map tasks=706104
# 		Total vcore-milliseconds taken by all reduce tasks=59053
# 		Total megabyte-milliseconds taken by all map tasks=1446100992
# 		Total megabyte-milliseconds taken by all reduce tasks=846583808
# 	Map-Reduce Framework
# 		Map input records=64
# 		Map output records=64
# 		Map output bytes=768
# 		Map output materialized bytes=170
# 		Input split bytes=106
# 		Combine input records=0
# 		Spilled Records=64
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=165
# 		CPU time spent (ms)=740
# 		Physical memory (bytes) snapshot=554954752
# 		Virtual memory (bytes) snapshot=8181432320
# 		Total committed heap usage (bytes)=727711744
# 	File Input Format Counters
# 		Bytes Read=196424
# 21/05/06 22:20:44 ERROR streaming.StreamJob: Job not successful!
# Streaming Command Failed!

# %%
# kill application with:
# ! yarn application -kill application_*
